# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random as rn
import math
# %matplotlib inline


from pylorentz import Momentum4

# %%
col_names = ["isPassed","m_catCoup_HybridFullRun2","m_weightCatCoup_HybridFullRun2","m_weight_MC",
             "y1.Pt","y1.Eta","y1.Phi","y1.E",
             "y2.Pt*1000.","y2.Eta","y2.Phi","y2.E",
             "jet0.pt","jet0.eta","jet0.phi","jet0.e",
             "jet1.pt","jet1.eta","jet1.phi","jet1.e",
             "jet2.pt","jet2.eta","jet2.phi","jet2.e",
             "jet3.pt","jet3.eta","jet3.phi","jet3.e",
             "jet4.pt","jet4.eta","jet4.phi","jet4.e",
             "jet5.pt","jet5.eta","jet5.phi","jet5.e",
             "jet6.pt","jet6.eta","jet6.phi","jet6.e",
             "jet7.pt","jet7.eta","jet7.phi","jet7.e",
             "jet8.pt","jet8.eta","jet8.phi","jet8.e",
             "jet9.pt","jet9.eta","jet9.phi","jet9.e",
             "jet10.pt","jet10.eta","jet10.phi","jet10.e"]

# %% [markdown]
# ### Loading pythia

# %%
signal = pd.read_csv("PowhegPy8EG_NNPDF30_VBFH125mc16a.csv",names=col_names,dtype="float32",nrows=104e3)#,nrows=104e3)
background = pd.read_csv("Sherpa2_yyjj_njetGeq2_mjj_gt350.csv",names=col_names,dtype="float32",nrows=302e3)#,nrows=256e3)

# %%
signal["signal"]= np.ones(signal.shape[0])
background["signal"] = np.zeros(background.shape[0])

# %%
df = pd.concat([signal,background], sort=False)

# %%
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### Load engineered features

# %%
njets = pd.read_csv("njets(10%total,VBF,non_res).txt",header=None,dtype="int").values.flatten()

# %%
pt_highest_pt_jet = pd.read_csv("pt_highest_pt_jet(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()

# %%
sum_pt_all_jets = pd.read_csv("sum_pt_all_jets(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()

# %%
number_central_jets = pd.read_csv("number_central_jets(10%total,VBF,non_res).txt",header=None,dtype="int").values.flatten()

# %%
invariant_mass_jet_system = pd.read_csv("invariant_mass_jet_system_real(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()

# %%
sum_trans_energy_particles = pd.read_csv("sum_trans_energy_particles(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
delta_phi_yy_jets = pd.read_csv("delta_phi_yy_jets(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
delta_rapidity_yy_jets = pd.read_csv("delta_rapidity_yy_jets(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
pt_j1_j2 = pd.read_csv("pt_j1_j2(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
m_j1_j2 = pd.read_csv("m_j1_j2_real(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
delta_y_j1_j2 = pd.read_csv("delta_y_j1_j2(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
delta_phi_j1_j2 = pd.read_csv("delta_phi_j1_j2(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
delta_eta_j1_j2 = pd.read_csv("delta_eta_j1_j2(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
pt_yy_j1 = pd.read_csv("pt_yy_j1(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
m_yy_j1 = pd.read_csv("m_yy_j1_real(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
pt_yy_jj = pd.read_csv("pt_yy_jj(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
m_yy_jj = pd.read_csv("m_yy_jj_real(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
eta_photon1 = pd.read_csv("eta_photon1(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
eta_photon2 = pd.read_csv("eta_photon2(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
pt_yy = pd.read_csv("pt_yy(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
rapidity_yy = pd.read_csv("rapidity_yy_real(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
forward_jet_etas = pd.read_csv("forward_jet_etas(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
m_yy_jF = pd.read_csv("m_yy_jF_real(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
p_H_T = pd.read_csv("p_H_T(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
m_yy = pd.read_csv("m_yy(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
pt_y1 = pd.read_csv("pt_y1(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
pt_y2 = pd.read_csv("pt_y2(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
### EXTRA FEATURES ###
pt_yy_thrust = pd.read_csv("pt_yy_thrust(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
delta_eta_yy = pd.read_csv("delta_eta_yy(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
eta_zepp = pd.read_csv("eta_zepp(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
phi_star_yy = pd.read_csv("phi_star_yy(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()
cos_theta_star_yy = pd.read_csv("cos_theta_star_yy(10%total,VBF,non_res).txt",header=None,dtype="float32").values.flatten()

# %%
features = list(zip(njets,pt_highest_pt_jet,sum_pt_all_jets,number_central_jets,invariant_mass_jet_system,
                sum_trans_energy_particles,delta_phi_yy_jets,delta_rapidity_yy_jets,pt_j1_j2,
                m_j1_j2,delta_y_j1_j2,delta_phi_j1_j2,delta_eta_j1_j2,pt_yy_j1,m_yy_j1,pt_yy_jj,
                m_yy_jj,eta_photon1,eta_photon2,pt_yy,rapidity_yy,forward_jet_etas,m_yy_jF,p_H_T,
                m_yy,pt_y1,pt_y2,pt_yy_thrust,delta_eta_yy,eta_zepp,phi_star_yy,cos_theta_star_yy))

# %%
feature_names = np.array(["njets","pt_highest_pt_jet","sum_pt_all_jets","number_central_jets","invariant_mass_jet_system",
                "sum_trans_energy_particles","delta_phi_yy_jets","delta_rapidity_yy_jets","pt_j1_j2",
                "m_j1_j2","delta_y_j1_j2","delta_phi_j1_j2","delta_eta_j1_j2","pt_yy_j1","m_yy_j1","pt_yy_jj",
                "m_yy_jj","eta_photon1","eta_photon2","pt_yy","rapidity_yy","forward_jet_etas","m_yy_jF","p_H_T",
                "m_yy","pt_y1","pt_y2","pt_yy_thrust","delta_eta_yy","eta_zepp","phi_star_yy","cos_theta_star_yy"])

# %%
features_df = pd.DataFrame(features,columns=feature_names)

# %%
signal = df.signal.values

# %%
features_df
# Out:
#         njets  pt_highest_pt_jet  sum_pt_all_jets  number_central_jets  \
# 0           3       85094.398438     1.914678e+05                    1
# 1           3      132530.000000     2.168200e+05                    2
# 2           3       50288.601562     1.274241e+05                    1
# 3           1       77802.101562     7.780210e+04                    0
# 4           4      189115.000000     3.248326e+05                    3
# ...       ...                ...              ...                  ...
# 405995      4       82535.101562     2.290460e+05                    3
# 405996      4      336428.000000     4.619379e+05                    3
# 405997      3      613026.000000     1.103711e+06                    3
# 405998      2       37217.000000     7.406340e+04                    0
# 405999      4      191540.000000     5.422284e+05                    4
#
#         invariant_mass_jet_system  sum_trans_energy_particles  \
# ...

# %%
signal.shape
# Out:
# (406000,)

# %%
features_df["signal"] = signal

# %%
features_df
# Out:
#         njets  pt_highest_pt_jet  sum_pt_all_jets  number_central_jets  \
# 0           3       85094.398438     1.914678e+05                    1
# 1           3      132530.000000     2.168200e+05                    2
# 2           3       50288.601562     1.274241e+05                    1
# 3           1       77802.101562     7.780210e+04                    0
# 4           4      189115.000000     3.248326e+05                    3
# ...       ...                ...              ...                  ...
# 405995      4       82535.101562     2.290460e+05                    3
# 405996      4      336428.000000     4.619379e+05                    3
# 405997      3      613026.000000     1.103711e+06                    3
# 405998      2       37217.000000     7.406340e+04                    0
# 405999      4      191540.000000     5.422284e+05                    4
#
#         invariant_mass_jet_system  sum_trans_energy_particles  \
# ...

# %%
features_df.to_csv("VBF_non_res_10%total", encoding="utf-8", index=False)

# %%
#df_test = pd.read_csv("pythia_features_total",dtype="float32")

# %%
#df_test
